# %%
import pandas as pd
import sys
import os

# %%
sys.path.append(os.path.abspath('C:/Users/teeyob/OilSight/scripts'))

# %%
from correlation import (load_data)

# %%
data = load_data('C:/Users/teeyob/OilSight/data/Copy of BrentOilPrices.csv', 'C:/Users/teeyob/OilSight/data/GDP.csv', 'C:/Users/teeyob/OilSight/data/Inflation.csv', 'C:/Users/teeyob/OilSight/data/ExchangeRate.csv')
# Out:
# C:\Users\teeyob\OilSight\scripts\correlation.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv(price_path, parse_dates=['Date'], index_col='Date')

# %% [markdown]
# Apply and evaluate LSTM

# %%
from model import (apply_lstm_model,forecast_var_model)
lstm_model = apply_lstm_model(data)
# Out:
# Epoch 1/10
# c:\Users\teeyob\OilSight\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 147ms/step - loss: 0.2666 - val_loss: 0.0789
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0507 - val_loss: 0.0555
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0647 - val_loss: 0.0483
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0366 - val_loss: 0.0538
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0395 - val_loss: 0.0507
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0395 - val_loss: 0.0449
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0304 - val_loss: 0.0445
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0329 - val_loss: 0.0433
# ...
